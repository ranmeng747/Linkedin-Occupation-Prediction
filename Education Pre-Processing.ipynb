# %%
import numpy as np
import pandas as pd
import json
import gzip
import seaborn as sns
import os
import math
import string
# %matplotlib inline

# %%
data_dir = '../Data/linkedin-crawled-profiles-dataset'
profiles_path = os.path.join(data_dir, 'linkedin.json')

num_profiles_loaded = 1000
profiles = []

for line in open(profiles_path, encoding = 'utf8'):
    if len(profiles) < num_profiles_loaded:
        line = json.loads(line)
        profiles.append(line)
    else:
        break

# %%
df = pd.DataFrame()
for i in profiles: 
    if "experience" and "education" and "skills" in i:
        df1 = pd.DataFrame.from_dict(i,orient='index')
        df1=df1.transpose()
        df=pd.concat([df,df1],axis = 0,ignore_index = True)

# %%
df.head()
# Out:
#                   _id                                          also_view  \
# 0         in-00000001  [{'url': 'http://www.linkedin.com/pub/krisa-dr...
# 1            in-00001  [{'url': 'http://www.linkedin.com/pub/peter-ki...
# 2            in-00006  [{'url': 'http://www.linkedin.com/pub/george-c...
# 3  in-000vijaychauhan  [{'url': 'http://in.linkedin.com/in/sandeeprag...
# 4    in-001adambutler  [{'url': 'http://uk.linkedin.com/in/paulbeier'...
#
#                                            education  \
# 0                                                NaN
# 1  [{'start': '2008', 'major': 'Economics', 'end'...
# 2  [{'major': 'Biophysics', 'end': '2009', 'name'...
# 3  [{'start': '1988', 'end': '1989', 'name': 'Eco...
# 4  [{'major': 'Product Design', 'end': '1994', 'n...
#
#                                               events  \
# 0                                                NaN
# 1  [{'from': 'Sahlgrenska University Hospital', '...
# 2  [{'from': 'Wyss Institute for Biologically Ins...
# 3                                                NaN
# 4  [{'from': 'Tigerprint', 'to': 'WHSmith', 'titl...
#
#                                           experience  \
# 0                                                NaN
# 1  [{'org': 'Johnson and Johnson', 'title': 'Seni...
# 2  [{'org': 'UCSF', 'title': 'Assistant Professor...
# 3                                                NaN
# 4  [{'org': 'Brand New Music', 'title': 'Founding...
#
#                                                group  \
# 0                                                NaN
# 1  {'affilition': ['ASMALLWORLD.net', 'Biomarker ...
# 2                                                NaN
# 3  {'member': 'Member of Project Management Insti...
# 4                                                NaN
#
#                                             homepage honors  \
# 0                                                NaN    NaN
# 1                                                NaN    NaN
# 2  {'BIOMOD': ['http://biomod.net/'], 'Company We...    NaN
# 3                                                NaN    NaN
# 4                                                NaN    NaN
#
#                     industry  \
# 0            Medical Devices
# 1            Pharmaceuticals
# 2                   Research
# 3       Aviation & Aerospace
# 4  Marketing and Advertising
#
#                                            interests interval  \
# 0                                                NaN      NaN
# 1                                                NaN       20
# 2                  personal genomics, nanotechnology        0
# 3                      Literature, Philosophy, Music      NaN
# 4  travelling,the sea,trying new things, trying t...       16
#
#                     locality  \
# 0              United States
# 1      Antwerp Area, Belgium
# 2  San Francisco, California
# 3        Chennai Area, India
# 4   Brighton, United Kingdom
#
#                                                 name  \
# 0  {'family_name': 'Mazalu MBA', 'given_name': 'D...
# 1   {'family_name': 'Forslund', 'given_name': 'Ann'}
# 2  {'family_name': 'Douglas', 'given_name': 'Shawn'}
# 3  {'family_name': 'Chauhan, PMP', 'given_name': ...
# 4   {'family_name': 'Adam', 'given_name': 'Butler,'}
#
#                                        overview_html  \
# 0                                                NaN
# 1  <dl id="overview"><dt id="overview-summary-cur...
# 2  <dl id="overview"><dt id="overview-summary-cur...
# 3                                                NaN
# 4                                                NaN
#
#                                               skills  \
# 0  [Key Account Development, Strategic Planning, ...
# 1                    [Molecular Biology, Biomarkers]
# 2  [DNA, Nanotechnology, Molecular Biology, Softw...
# 3  [Program Management, French, Avionics, Embedde...
# 4  [Digital Strategy, Integrated Marketing, Digit...
#
#                                          specilities  \
# 0                                                NaN
# 1  Biomarkers in Oncology, Cancer Genomics, Molec...
# 2                                                NaN
# 3                                                NaN
# 4  A passion for Brands, coupled with experience ...
#
#                                              summary  \
# 0  SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 1  Ph.D. scientist with background in cancer rese...
# 2  I am interested in inventing new methods to co...
# 3  Experience in Avionics Systems, Embedded Syste...
# 4  Integrating creative design with commercial ma...
#
#                                          url
# 0        http://www.linkedin.com/in/00000001
# 1            http://be.linkedin.com/in/00001
# 2           http://www.linkedin.com/in/00006
# 3  http://in.linkedin.com/in/000vijaychauhan
# 4    http://uk.linkedin.com/in/001adambutler

# %%
# Extract information about major, highest degree and institution from education column
def add_edu_info(df):
    df2 = df[df['education'].notnull()].copy()

    major = []
    institution = []
    degree = []
    
    for profile in df2['education']:
        personal_major = [] # majors for a particular profile
        personal_institution = []
        personal_degree = []
        for record in profile:
            if "major" in record: 
                personal_major.append(record['major'])
                         
            if "name" in record:
                personal_institution.append(record['name'])
            
            if "degree" in record:
                personal_degree.append(record['degree'])
                
        major.append(personal_major)
        institution.append(personal_institution)
        degree.append(personal_degree) 
        
    major = [float('nan') if x == [] else x for x in major] #replace empty list with NaN for consistency
    df2['major'] = major
    institution = [float('nan') if x == [] else x for x in institution]
    df2['institution'] = institution
    degree = [float('nan') if x == [] else x[0] for x in degree] # Assuming the most recent degree is the highest degree obtained
    df2['degree'] = degree
    
    df = pd.merge(df, df2[['_id', 'major', 'institution', 'degree']], on=['_id'], how = 'left')
    
    return df

# %%
print('Original df shape: ', df.shape)

df = add_edu_info(df)
print('Add majors and instituion', df.shape)
# Out:
# Original df shape:  (703, 18)
# Add majors and instituion (703, 21)

# %%
df['degree'].value_counts().loc[lambda x : x>1]
# Out:
# MBA                                           38
# BA                                            17
# Master                                        15
# BS                                            13
# MS                                            10
# Bachelor of Science                            9
# PhD                                            8
# Bachelor's degree                              7
# Bachelor                                       6
# B.E.                                           5
# B.A.                                           5
# B.S.                                           5
# Bachelors                                      4
# Ph.D.                                          4
# Certificate                                    4
# Master of Business Administration (MBA)        4
# MSc                                            3
# Executive MBA                                  3
# Bachelor of Science (BSc)                      3
# Bachelor of Science (BS)                       3
# Master's degree                                3
# BBA                                            3
# MA                                             3
# BE                                             3
# PGDM                                           3
# M.Sc.                                          3
# M.A.                                           3
# MHRM                                           2
# Master of Science (MS)                         2
# PGDBM                                          2
# Master of Science                              2
# Masters in Business Administration             2
# BA (Hons)                                      2
# Ph.D                                           2
# none                                           2
# Computer Animation                             2
# Master of Business Administration (M.B.A.)     2
# PGCE                                           2
# Master of Business Administration              2
# Associate                                      2
# Business                                       2
# M.Sc                                           2
# Name: degree, dtype: int64

# %%
def remove_punctuation(s):
    translator = str.maketrans('', '', string.punctuation)
    
    return s.translate(translator)

# %%
def clean_degree(df):
    lst = []
    
    for degree in df['degree']:
        if type(degree) == float:
            lst.append(degree) # Keep NaN values without further processing
        else:
            degree = remove_punctuation(degree.upper())
            
            if 'PHD' in degree:
                degree = 'PHD'
                
            if "BUSINESS ADMINISTRATION" in degree or 'MBA' in degree:
                degree = 'MBA'
            
            if "BACHELOR OF SCIENCE" in degree or "BSC" in degree:
                degree = 'BS'
            
            if "MASTER OF SCIENCE" in degree or 'MS' in degree or 'MSC' in degree:
                degree = 'MS'
            
            if degree == "BACHELORS DEGREE" or degree == 'BACHELORS':
                degree = 'BACHELOR'
                
            if degree == "MASTERS DEGREE" or degree == 'MASTERS':
                degree = 'MASTER'
                
            lst.append(degree)
    
    df['degree'] = lst
    
    return df

# %%
clean_degree(df)['degree'].value_counts().loc[lambda x : x>1]
# Out:
# MBA                   61
# BS                    47
# MS                    39
# MASTER                23
# BA                    23
# PHD                   18
# BACHELOR              18
# BE                     8
# MA                     7
# CERTIFICATE            4
# BA HONS                3
# BBA                    3
# PGDM                   3
# BTECH                  2
# BUSINESS               2
# ASSOCIATE              2
# NONE                   2
# COMPUTER SCIENCE       2
# MHRM                   2
# PGCE                   2
# PGDBM                  2
# COMPUTER ANIMATION     2
# BCS                    2
# Name: degree, dtype: int64

# %%
df.head()
# Out:
#                   _id                                          also_view  \
# 0         in-00000001  [{'url': 'http://www.linkedin.com/pub/krisa-dr...
# 1            in-00001  [{'url': 'http://www.linkedin.com/pub/peter-ki...
# 2            in-00006  [{'url': 'http://www.linkedin.com/pub/george-c...
# 3  in-000vijaychauhan  [{'url': 'http://in.linkedin.com/in/sandeeprag...
# 4    in-001adambutler  [{'url': 'http://uk.linkedin.com/in/paulbeier'...
#
#                                            education  \
# 0                                                NaN
# 1  [{'start': '2008', 'major': 'Economics', 'end'...
# 2  [{'major': 'Biophysics', 'end': '2009', 'name'...
# 3  [{'start': '1988', 'end': '1989', 'name': 'Eco...
# 4  [{'major': 'Product Design', 'end': '1994', 'n...
#
#                                               events  \
# 0                                                NaN
# 1  [{'from': 'Sahlgrenska University Hospital', '...
# 2  [{'from': 'Wyss Institute for Biologically Ins...
# 3                                                NaN
# 4  [{'from': 'Tigerprint', 'to': 'WHSmith', 'titl...
#
#                                           experience  \
# 0                                                NaN
# 1  [{'org': 'Johnson and Johnson', 'title': 'Seni...
# 2  [{'org': 'UCSF', 'title': 'Assistant Professor...
# 3                                                NaN
# 4  [{'org': 'Brand New Music', 'title': 'Founding...
#
#                                                group  \
# 0                                                NaN
# 1  {'affilition': ['ASMALLWORLD.net', 'Biomarker ...
# 2                                                NaN
# 3  {'member': 'Member of Project Management Insti...
# 4                                                NaN
#
#                                             homepage honors  \
# 0                                                NaN    NaN
# 1                                                NaN    NaN
# 2  {'BIOMOD': ['http://biomod.net/'], 'Company We...    NaN
# 3                                                NaN    NaN
# 4                                                NaN    NaN
#
#                     industry  \
# 0            Medical Devices
# 1            Pharmaceuticals
# 2                   Research
# 3       Aviation & Aerospace
# 4  Marketing and Advertising
#
#                                            interests   ...     \
# 0                                                NaN   ...
# 1                                                NaN   ...
# 2                  personal genomics, nanotechnology   ...
# 3                      Literature, Philosophy, Music   ...
# 4  travelling,the sea,trying new things, trying t...   ...
#
#                     locality  \
# 0              United States
# 1      Antwerp Area, Belgium
# 2  San Francisco, California
# 3        Chennai Area, India
# 4   Brighton, United Kingdom
#
#                                                 name  \
# 0  {'family_name': 'Mazalu MBA', 'given_name': 'D...
# 1   {'family_name': 'Forslund', 'given_name': 'Ann'}
# 2  {'family_name': 'Douglas', 'given_name': 'Shawn'}
# 3  {'family_name': 'Chauhan, PMP', 'given_name': ...
# 4   {'family_name': 'Adam', 'given_name': 'Butler,'}
#
#                                        overview_html  \
# 0                                                NaN
# 1  <dl id="overview"><dt id="overview-summary-cur...
# 2  <dl id="overview"><dt id="overview-summary-cur...
# 3                                                NaN
# 4                                                NaN
#
#                                               skills  \
# 0  [Key Account Development, Strategic Planning, ...
# 1                    [Molecular Biology, Biomarkers]
# 2  [DNA, Nanotechnology, Molecular Biology, Softw...
# 3  [Program Management, French, Avionics, Embedde...
# 4  [Digital Strategy, Integrated Marketing, Digit...
#
#                                          specilities  \
# 0                                                NaN
# 1  Biomarkers in Oncology, Cancer Genomics, Molec...
# 2                                                NaN
# 3                                                NaN
# 4  A passion for Brands, coupled with experience ...
#
#                                              summary  \
# 0  SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 1  Ph.D. scientist with background in cancer rese...
# 2  I am interested in inventing new methods to co...
# 3  Experience in Avionics Systems, Embedded Syste...
# 4  Integrating creative design with commercial ma...
#
#                                          url  \
# 0        http://www.linkedin.com/in/00000001
# 1            http://be.linkedin.com/in/00001
# 2           http://www.linkedin.com/in/00006
# 3  http://in.linkedin.com/in/000vijaychauhan
# 4    http://uk.linkedin.com/in/001adambutler
#
#                                                major  \
# 0                                                NaN
# 1  [Economics, Cancer genomics, Biology, Medicine...
# 2                     [Biophysics, Computer Science]
# 3                                                NaN
# 4                                   [Product Design]
#
#                                          institution   degree
# 0                                                NaN      NaN
# 1  [Columbia University - Columbia Business Schoo...      PHD
# 2              [Harvard University, Yale University]      PHD
# 3  [Ecole nationale supérieure de l'Aéronautique ...      NaN
# 4                           [Bournemouth University]  BA HONS
#
# [5 rows x 21 columns]
